# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
data = pd.read_csv("C:/Users/tusha/student.csv")

# %%
data.head()
# Out:
#    Maths  Physics  Chemistry  Result
# 0     17       27         22       0
# 1     72       82         77       1
# 2     97       18         13       0
# 3      8       42         37       0
# 4     32       25         20       0

# %%
data.tail()
# Out:
#      Maths  Physics  Chemistry  Result
# 995      4       48         64       0
# 996     63       22         88       0
# 997     90       64         43       1
# 998     67       41          6       0
# 999     92       74          9       0

# %%
data.shape
# Out:
# (1000, 4)

# %%
data.describe()
# Out:
#              Maths      Physics    Chemistry       Result
# count  1000.000000  1000.000000  1000.000000  1000.000000
# mean     50.842000    52.316000    52.239000     0.245000
# std      29.238775    24.801114    27.397052     0.430302
# min       0.000000    10.000000     5.000000     0.000000
# 25%      26.000000    31.000000    29.750000     0.000000
# 50%      51.000000    51.000000    53.000000     0.000000
# 75%      76.000000    74.000000    76.000000     0.000000
# max     100.000000    95.000000    99.000000     1.000000

# %%
data.columns
# Out:
# Index(['Maths', 'Physics', 'Chemistry', 'Result'], dtype='object')

# %%
data.nunique()
# Out:
# Maths        101
# Physics       86
# Chemistry     95
# Result         2
# dtype: int64

# %%
data['Maths'].unique()
# Out:
# array([ 17,  72,  97,   8,  32,  15,  63,  57,  60,  83,  48, 100,  26,
#         12,  62,   3,  49,  55,  77,  98,   0,  89,  34,  92,  29,  75,
#         13,  40,   2,  69,   1,  87,  27,  54,  67,  28,  56,  70,  44,
#         86,  58,  37,  53,  71,  82,  23,  80,  95,  42,  91,  64,  85,
#         24,  38,  36,  50,   4,  61,  31,  51,  22,  46,  99,  94,  47,
#         11,  84,  65,  20,  66,  93,   5,  39,  90,  78,  74,  21,  25,
#         73,  45,  16,   7,  52,  68,  79,  76,  81,   9,  10,  96,  35,
#         14,  41,  43,  33,  18,  88,   6,  30,  19,  59], dtype=int64)

# %%
# Cleaning the data

# %%
data.isnull().sum()
# Out:
# Maths        0
# Physics      0
# Chemistry    0
# Result       0
# dtype: int64

# %%
# student = data.drop(['Maths'],axis = 1) if you want to drop a certain column

# %%
#3 Relationship analysis

# %%
correlation = data.corr()

# %%
sns.heatmap(correlation, xticklabels= correlation.columns, yticklabels = correlation.columns , annot = True)

# %%
sns.pairplot(data)

# %%
sns.distplot(data['Maths'])

# %%
sns.distplot(data['Physics'])
